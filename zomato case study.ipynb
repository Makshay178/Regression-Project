# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ZomatoData = pd.read_csv(r'C:\Users\Akshay\Desktop\IVY\Python\Python Pred Modeling All notebooks + Datasets\Python Datasets\Regression Datasets\ZomatoData.csv',encoding='latin')
print('Shape before deleting the duplicate values',ZomatoData.shape)
ZomatoData = ZomatoData.drop_duplicates()
print('Shape after deleting the duplicate values',ZomatoData.shape)
ZomatoData.head(5)
# Out:
# Shape before deleting the duplicate values (9551, 19)
# Shape after deleting the duplicate values (9551, 19)
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# ...

# %% [raw]
# Defining the Problem statement
# Create a Predictive model which can predict the future Rating of a restaurant
# Target Variable : Rating
# Predictors : Location,menu,cost,etc.

# %%
#looking at distribution of target variable
# %matplotlib inline
ZomatoData['Rating'].hist()

# %%
ZomatoData.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
ZomatoData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 19 columns):
# Restaurant ID           9551 non-null int64
# Restaurant Name         9551 non-null object
# Country Code            9551 non-null int64
# City                    9551 non-null object
# Address                 9551 non-null object
# Locality                9551 non-null object
# Locality Verbose        9551 non-null object
# Longitude               9551 non-null float64
# Latitude                9551 non-null float64
# Cuisines                9542 non-null object
# Currency                9551 non-null object
# Has Table booking       9551 non-null object
# Has Online delivery     9551 non-null object
# Is delivering now       9551 non-null object
# Switch to order menu    9551 non-null object
# Price range             9551 non-null int64
# Votes                   9551 non-null int64
# Average Cost for two    9551 non-null int64
# ...

# %%
ZomatoData.describe(include='all')
# Out:
#         Restaurant ID  Restaurant Name  Country Code       City  \
# count    9.551000e+03             9551   9551.000000       9551
# unique            NaN             7446           NaN        141
# top               NaN  Cafe Coffee Day           NaN  New Delhi
# freq              NaN               83           NaN       5473
# mean     9.051128e+06              NaN     18.365616        NaN
# std      8.791521e+06              NaN     56.750546        NaN
# min      5.300000e+01              NaN      1.000000        NaN
# 25%      3.019625e+05              NaN      1.000000        NaN
# 50%      6.004089e+06              NaN      1.000000        NaN
# 75%      1.835229e+07              NaN      1.000000        NaN
# max      1.850065e+07              NaN    216.000000        NaN
#
#                            Address         Locality  \
# count                         9551             9551
# unique                        8918             1208
# ...

# %%
ZomatoData.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Votes                   1012
# Average Cost for two     140
# Rating                    33
# dtype: int64

# %%
def cuisines_count(inpstr):
    Numcuisines = len(str(inpstr).split(','))
    return(Numcuisines)

# %%
ZomatoData['Cuisines_Count'] = ZomatoData['Cuisines'].apply(cuisines_count)
ZomatoData.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
UselessColumns = ['Restaurant ID','Restaurant Name','City','Address','Locality','Locality Verbose','Cuisines']
ZomatoData = ZomatoData.drop(UselessColumns,axis=1)
ZomatoData.head()
# Out:
#    Country Code   Longitude   Latitude          Currency Has Table booking  \
# 0           162  121.027535  14.565443  Botswana Pula(P)               Yes
# 1           162  121.014101  14.553708  Botswana Pula(P)               Yes
# 2           162  121.056831  14.581404  Botswana Pula(P)               Yes
# 3           162  121.056475  14.585318  Botswana Pula(P)                No
# 4           162  121.057508  14.584450  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# 1                  No                No                   No            3
# 2                  No                No                   No            4
# 3                  No                No                   No            4
# 4                  No                No                   No            4
#
#    Votes  Average Cost for two  Rating  Cuisines_Count
# ...

# %% [raw]
# # Bar Chart Representation(Categorical Variable)

# %%
def PlotBarCharts(inpData,ColstoPlot):
    # %matplotlib inline
    import matplotlib.pyplot as plt
    figs,subplot = plt.subplots(nrows=1,ncols=len(ColstoPlot),figsize=(20,5))
    figs.suptitle('Bar Charts of: '+str(ColstoPlot) )
    
    for colName , plotnumber in zip(ColstoPlot,range(len(ColstoPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subplot[plotnumber])

# %%
PlotBarCharts(inpData = ZomatoData , ColstoPlot = ['Country Code','Currency','Has Table booking','Has Online delivery',
                                                   'Is delivering now','Switch to order menu','Price range'])

# %% [raw]
# # Bar Chart Ineterpretation-
# -Represent frequencies of each category on Y-axis
# -In Switch to order column only one value is skewed which is not that much helpful in algorithm
# -"Country Code", "Currency", "is delivering now" and "Switch to order menu" are too skewed.
#
# Only three categorical variables are selected for further analysis.
#  'Has Table booking', 'Has Online delivery', 'Price range'.

# %% [raw]
# # Histogram Representation(Continuios Variable)
# Based on the Basic Data Exploration, There are four continuous predictor variables ''Longitude', 'Latitude','Votes', and 'Average Cost for two'

# %%
ZomatoData.hist(['Longitude', 'Latitude','Votes','Average Cost for two'],figsize = (18,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A6DB4A7208>,
# ...
#       dtype=object)

# %% [markdown]
#  Histogram Interpretation
# Selected Continuous Variables:
#
# Longitude : Selected. The distribution is good.
# Latitude: Selected. The distribution is good.
# Votes: Selected. Outliers seen beyond 300000, need to treat them.
# Average Cost for two: Selected. Outliers seen beyond 4000, need to treat them.

# %% [markdown]
# ## # Outlier Treatment

# %%
ZomatoData['Votes'][ZomatoData['Votes']<4000].sort_values(ascending = False)
# Out:
# 7863    3986
# 821     3848
# 3992    3697
# 3119    3591
# 1861    3569
# 731     3533
# 6848    3530
# 5007    3495
# 3083    3413
# 2300    3374
# 2490    3370
# 7033    3311
# 2495    3244
# 3026    3206
# 3095    3164
# 501     3157
# 511     3074
# 3055    3010
# 3599    3010
# 3589    3002
# 4649    2860
# 9167    2847
# 1258    2843
# 4087    2826
# 1555    2806
# 3438    2777
# 3316    2724
# 3060    2689
# 2492    2662
# 3016    2639
#         ...
# 2675       0
# 2672       0
# 8917       0
# 2671       0
# 8916       0
# 8912       0
# 8907       0
# 8906       0
# 8904       0
# 8902       0
# 8901       0
# 8900       0
# 8899       0
# 8544       0
# 8545       0
# 8897       0
# 8558       0
# 8560       0
# 2581       0
# 8895       0
# 2614       0
# 2615       0
# 2618       0
# 2620       0
# 2663       0
# 2666       0
# 2667       0
# 2668       0
# 2669       0
# 4783       0
# Name: Votes, Length: 9532, dtype: int64

# %%
ZomatoData['Votes'][ZomatoData['Votes']>4000] = 3986

# %%
ZomatoData['Average Cost for two'][ZomatoData['Average Cost for two']<50000].sort_values(ascending = False)
# Out:
# 7543    8000
# 4088    7000
# 4087    6500
# 7499    6000
# 7494    6000
# 8       6000
# 7538    6000
# 7492    6000
# 7539    5500
# 7522    5500
# 7512    5100
# 7521    5000
# 7485    5000
# 7536    5000
# 4298    5000
# 1217    5000
# 7534    5000
# 4958    5000
# 3064    5000
# 7296    5000
# 7514    5000
# 7297    5000
# 7497    5000
# 3594    4800
# 5838    4700
# 7510    4500
# 7529    4500
# 4019    4500
# 9512    4500
# 7513    4500
#         ...
# 157       10
# 338       10
# 341       10
# 167       10
# 153       10
# 151       10
# 336       10
# 527       10
# 269        7
# 315        7
# 317        7
# 318        7
# 9254       0
# 277        0
# 2364       0
# 407        0
# 634        0
# 397        0
# 637        0
# 639        0
# 240        0
# 851        0
# 9242       0
# 2368       0
# 346        0
# 201        0
# 87         0
# 85         0
# 677        0
# 84         0
# Name: Average Cost for two, Length: 9530, dtype: int64

# %%
ZomatoData['Average Cost for two'][ZomatoData['Average Cost for two']>50000]=8000

# %% [markdown]
# # Visualizing after treament of Outliers

# %%
ZomatoData.hist(['Votes','Average Cost for two'],figsize=(18,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A6DE859940>,
# ...
#       dtype=object)

# %%
ZomatoData.isnull().sum()
# Out:
# Country Code            0
# Longitude               0
# Latitude                0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Votes                   0
# Average Cost for two    0
# Rating                  0
# Cuisines_Count          0
# dtype: int64

# %% [raw]
# # No Null Values

# %% [markdown]
# ### Feature Selection

# %% [raw]
# Continuous vs Continuous -- Scatter Plot

# %%
Continuouscols = ['Longitude', 'Latitude','Votes','Average Cost for two']

# %%
for predictor in Continuouscols:
    ZomatoData.plot.scatter(x=predictor,y='Rating',figsize = (10,5),title = predictor + ' Vs' + ' Rating')

# %% [markdown]
# Final Selected Columns
# Votes
# Average Cost for two

# %% [raw]
# Categorical vs Continuous -  Box Plot

# %%
CategoricalCols = ['Has Table booking','Has Online delivery','Price range']

# %%
import matplotlib.pyplot as plt

fig,PlotCanvas = plt.subplots(nrows = 1 ,ncols = len(CategoricalCols),figsize = (18,5))

for predictorcol,i in zip(CategoricalCols,range(len(CategoricalCols))):
    ZomatoData.boxplot(column = 'Rating',by = predictorcol,figsize = (5,5),vert = True , ax = PlotCanvas[i])

# %% [markdown]
# # Statistical Feature Selection (Categorical vs Continuous)(ANOVA)

# %%
def functionAnova(inpData , TargetVariable ,CategoricalPredictorList ):
    from scipy.stats import f_oneway
    
    
    SelectedPredictors = []
    
    print('-----ANOVA Result-----\n')
    for predictor in CategoricalPredictorList:
        CategoryGroupLists = inpData.groupby(predictor)[TargetVariable].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)
        
        
        if (AnovaResults[1]<0.05):
            print(predictor,'is correlated with',TargetVariable,'| P-Value:',AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            
    return(SelectedPredictors)

# %%
CategoricalPredictorList=['Has Table booking', 'Has Online delivery', 'Price range']
functionAnova(inpData = ZomatoData , TargetVariable= 'Rating',CategoricalPredictorList = CategoricalPredictorList)
# Out:
# -----ANOVA Result-----
#
# Has Table booking is correlated with Rating | P-Value: 3.9393041304297214e-82
# Has Online delivery is correlated with Rating | P-Value: 1.6952587420575958e-92
# Price range is correlated with Rating | P-Value: 0.0
# ['Has Table booking', 'Has Online delivery', 'Price range']

# %% [markdown]
# All categorical variables are correlated with the Target variable.

# %% [markdown]
# # Selecting Final Predictors for ML

# %%
SelectedColumns = ['Votes','Average Cost for two','Has Table booking', 'Has Online delivery', 'Price range']
DataforML = ZomatoData[SelectedColumns]
DataforML.head()
# Out:
#    Votes  Average Cost for two Has Table booking Has Online delivery  \
# 0    314                  1100               Yes                  No
# 1    591                  1200               Yes                  No
# 2    270                  4000               Yes                  No
# 3    365                  1500                No                  No
# 4    229                  1500               Yes                  No
#
#    Price range
# 0            3
# 1            3
# 2            4
# 3            4
# 4            4

# %%
DataforML.to_pickle('DataforML.pkl')

# %%
#converting the Binary Nominal Variable to Numeric

DataforML['Has Table booking'].replace({'Yes':1,'No':0},inplace=True)
DataforML['Has Online delivery'].replace({'Yes':1,'No':0},inplace=True)

# %%
DataforML_Numeric = pd.get_dummies(DataforML)
DataforML_Numeric['Rating'] = ZomatoData['Rating']
DataforML_Numeric.head()
# Out:
#    Votes  Average Cost for two  Has Table booking  Has Online delivery  \
# 0    314                  1100                  1                    0
# 1    591                  1200                  1                    0
# 2    270                  4000                  1                    0
# 3    365                  1500                  0                    0
# 4    229                  1500                  1                    0
#
#    Price range  Rating
# 0            3     4.8
# 1            3     4.5
# 2            4     4.4
# 3            4     4.9
# 4            4     4.8

# %%
DataforML_Numeric.columns
# Out:
# Index(['Votes', 'Average Cost for two', 'Has Table booking',
#        'Has Online delivery', 'Price range', 'Rating'],
#       dtype='object')

# %%
TargetVariable = 'Rating'
Predictors = ['Votes', 'Average Cost for two', 'Has Table booking','Has Online delivery', 'Price range']

X = DataforML_Numeric[Predictors].values
y = DataforML_Numeric[TargetVariable].values

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test  = train_test_split(X,y,test_size = 0.3, random_state=428)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (6685, 5)
# (2866, 5)
# (6685,)
# (2866,)

# %% [markdown]
# # Standardization and Normalization of Data

# %%
# On this data Min Max Normalization produced better results
from sklearn.preprocessing import MinMaxScaler
PredictorScaler = MinMaxScaler()
PRF = PredictorScaler.fit(X)
X = PRF.transform(X)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (7640, 5)
# (1911, 5)
# (6685,)
# (2866,)

# %% [markdown]
# # Multiple Regression

# %%
from sklearn.linear_model import LinearRegression
R = LinearRegression()
print(R)
LREG = R.fit(X_train,Y_train)
prediction = LREG.predict(X_test)

# Taking the standardized values to original scale

from sklearn import metrics
print('R2 Value:',metrics.r2_score(y_train,LREG.predict(X_train)))

print('\n------- Model Validation and Accuracy Calculation ---------')

TestingDataResults = pd.DataFrame(data = X_test , columns =Predictors)
TestingDataResults[TargetVariable] = y_test
TestingDataResults[('Predicted' + TargetVariable)] = np.round(prediction)
print(TestingDataResults[[TargetVariable,'Predicted'+TargetVariable]].head())

TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Rating']-TestingDataResults['PredictedRating']))/TestingDataResults['Rating'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)

def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

from sklearn.model_selection import cross_val_score

Accuracy_Values=cross_val_score(R, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# R2 Value: -0.00025573602260009487
#
# ------- Model Validation and Accuracy Calculation ---------
#    Rating  PredictedRating
# 0     2.1              3.0
# 1     4.1              3.0
# 2     3.2              3.0
# 3     4.4              3.0
# 4     3.5              3.0
# Mean Accuracy on test data: 44.4911372682455
# Median Accuracy on test data: 81.08108108108108
#
# Accuracy values for 10-fold Cross Validation:
#  [73.07128832 57.23634237 61.61405423 59.97790149 62.17608774 29.03036814
#  48.84028175 51.06832392 40.27174351 53.61838933]
#
# Final Average Accuracy of the model: 53.69
